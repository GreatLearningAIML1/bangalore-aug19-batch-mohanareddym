# %% [markdown]
# # External Lab

# %% [markdown]
# # Part-1

# %% [markdown]
# ## About the dataset
#
# This is perhaps the best known database to be found in the pattern recognition literature. The data set contains 3 classes of 50 instances each, where each class refers to a type of iris plant.  One class is linearly separable from the other 2; the latter are NOT linearly separable from each other.
#
# Attribute Information:
#    1. sepal length in cm
#    2. sepal width in cm
#    3. petal length in cm
#    4. petal width in cm
#    5. class:
#       -- Iris Setosa
#       -- Iris Versicolour
#       -- Iris Virginica

# %% [markdown]
# ### Read the dataset and store it in the dataframe named Iris

# %%
import pandas as pd
import numpy as np

### for Easy understanding i am converting Sepal lenght to SL , Sepal Width to SW and Petal Lenght to PL and Petal Width to PW .

# %%
lris = pd.read_csv('Iris.csv')
print(lris)
# Out:
#       SL   SW   PL   PW           Class
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# 5    5.4  3.9  1.7  0.4     Iris-setosa
# 6    4.6  3.4  1.4  0.3     Iris-setosa
# 7    5.0  3.4  1.5  0.2     Iris-setosa
# 8    4.4  2.9  1.4  0.2     Iris-setosa
# 9    4.9  3.1  1.5  0.1     Iris-setosa
# 10   5.4  3.7  1.5  0.2     Iris-setosa
# 11   4.8  3.4  1.6  0.2     Iris-setosa
# 12   4.8  3.0  1.4  0.1     Iris-setosa
# 13   4.3  3.0  1.1  0.1     Iris-setosa
# 14   5.8  4.0  1.2  0.2     Iris-setosa
# 15   5.7  4.4  1.5  0.4     Iris-setosa
# 16   5.4  3.9  1.3  0.4     Iris-setosa
# 17   5.1  3.5  1.4  0.3     Iris-setosa
# 18   5.7  3.8  1.7  0.3     Iris-setosa
# 19   5.1  3.8  1.5  0.3     Iris-setosa
# 20   5.4  3.4  1.7  0.2     Iris-setosa
# 21   5.1  3.7  1.5  0.4     Iris-setosa
# ...

# %% [markdown]
# ### Find out the datatypes of each and every column

# %%
lris = pd.read_csv('Iris.csv')
print ("Data types of each column is \n",lris.dtypes)
# Out:
# Data types of each column is
#  SL       float64
# SW       float64
# PL       float64
# PW       float64
# Class     object
# dtype: object

# %% [markdown]
# ### Print top 10 & bottom 10 samples from the dataframe

# %%
lris = pd.read_csv('Iris.csv')
print("header of the data frame is: \n ",lris.head(10))
print('\n')
print("tail of the data frame is :\n",lris.tail(10))
# Out:
# header of the data frame is:
#       SL   SW   PL   PW        Class
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa
# 5  5.4  3.9  1.7  0.4  Iris-setosa
# 6  4.6  3.4  1.4  0.3  Iris-setosa
# 7  5.0  3.4  1.5  0.2  Iris-setosa
# 8  4.4  2.9  1.4  0.2  Iris-setosa
# 9  4.9  3.1  1.5  0.1  Iris-setosa
#
#
# tail of the data frame is :
#        SL   SW   PL   PW           Class
# 140  6.7  3.1  5.6  2.4  Iris-virginica
# 141  6.9  3.1  5.1  2.3  Iris-virginica
# 142  5.8  2.7  5.1  1.9  Iris-virginica
# 143  6.8  3.2  5.9  2.3  Iris-virginica
# 144  6.7  3.3  5.7  2.5  Iris-virginica
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica

# %% [markdown]
# ### Find the shape of the dataset

# %%
lris = pd.read_csv('Iris.csv')
print("The shape of the data frame is :",lris.shape)
# Out:
# The shape of the data frame is : (150, 5)

# %% [markdown]
# ### Set the index of the dataframe to be the first column

# %%
lris = pd.read_csv('Iris.csv')
lris.head()
### for Easy understanding i am converting Sepal lenght to SL , Sepal Width to SW and Petal Lenght to PL and Petal Width to PW .
# Out:
#     SL   SW   PL   PW        Class
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %%
print(" The head after Changingn the Index to the First Column \n", lris.set_index("SL",inplace=False))
# Out:
#  The head after Changingn the Index to the First Column
#        SW   PL   PW           Class
# SL
# 5.1  3.5  1.4  0.2     Iris-setosa
# 4.9  3.0  1.4  0.2     Iris-setosa
# 4.7  3.2  1.3  0.2     Iris-setosa
# 4.6  3.1  1.5  0.2     Iris-setosa
# 5.0  3.6  1.4  0.2     Iris-setosa
# 5.4  3.9  1.7  0.4     Iris-setosa
# 4.6  3.4  1.4  0.3     Iris-setosa
# 5.0  3.4  1.5  0.2     Iris-setosa
# 4.4  2.9  1.4  0.2     Iris-setosa
# 4.9  3.1  1.5  0.1     Iris-setosa
# 5.4  3.7  1.5  0.2     Iris-setosa
# 4.8  3.4  1.6  0.2     Iris-setosa
# 4.8  3.0  1.4  0.1     Iris-setosa
# 4.3  3.0  1.1  0.1     Iris-setosa
# 5.8  4.0  1.2  0.2     Iris-setosa
# 5.7  4.4  1.5  0.4     Iris-setosa
# 5.4  3.9  1.3  0.4     Iris-setosa
# 5.1  3.5  1.4  0.3     Iris-setosa
# 5.7  3.8  1.7  0.3     Iris-setosa
# 5.1  3.8  1.5  0.3     Iris-setosa
# 5.4  3.4  1.7  0.2     Iris-setosa
# 5.1  3.7  1.5  0.4     Iris-setosa
# 4.6  3.6  1.0  0.2     Iris-setosa
# 5.1  3.3  1.7  0.5     Iris-setosa
# ...

# %% [markdown]
# ### Use iloc function to print all the rows of the 3rd column

# %%
lris = pd.read_csv('Iris.csv')
print ("The 3rd column with the all the rows of lrisis \n",lris.iloc[:,3])
# Out:
# The 3rd column with the all the rows of lrisis
#  0      0.2
# 1      0.2
# 2      0.2
# 3      0.2
# 4      0.2
# 5      0.4
# 6      0.3
# 7      0.2
# 8      0.2
# 9      0.1
# 10     0.2
# 11     0.2
# 12     0.1
# 13     0.1
# 14     0.2
# 15     0.4
# 16     0.4
# 17     0.3
# 18     0.3
# 19     0.3
# 20     0.2
# 21     0.4
# 22     0.2
# 23     0.5
# 24     0.2
# 25     0.2
# 26     0.4
# 27     0.2
# 28     0.2
# 29     0.2
#       ...
# 120    2.3
# 121    2.0
# 122    2.0
# 123    1.8
# 124    2.1
# 125    1.8
# 126    1.8
# 127    1.8
# 128    2.1
# 129    1.6
# 130    1.9
# 131    2.0
# 132    2.2
# 133    1.5
# 134    1.4
# 135    2.3
# 136    2.4
# 137    1.8
# 138    1.8
# 139    2.1
# 140    2.4
# 141    2.3
# 142    1.9
# 143    2.3
# 144    2.5
# 145    2.3
# 146    1.9
# 147    2.0
# 148    2.3
# 149    1.8
# Name: Petal width (in cm), Length: 150, dtype: float64

# %% [markdown]
# ### Slicing
# Print only the Sepal width and Sepal Length for first 10 rows

# %%
lris = pd.read_csv('Iris.csv')
print("The first 10 Rows with Sepal length and with Sepal with are \n",lris.iloc[0:10,[0,1]])
# Out:
# The first 10 Rows with Sepal length and with Sepal with are
#     Sepal_Length (in cm)  Sepal_Width in (cm)
# 0                   5.1                  3.5
# 1                   4.9                  3.0
# 2                   4.7                  3.2
# 3                   4.6                  3.1
# 4                   5.0                  3.6
# 5                   5.4                  3.9
# 6                   4.6                  3.4
# 7                   5.0                  3.4
# 8                   4.4                  2.9
# 9                   4.9                  3.1

# %% [markdown]
# ### Using Logical statements for indexing
# Print all the columns of row which has class name "Iris-setosa"

# %%
lris = pd.read_csv('Iris.csv')
print("After filtering the data with Iris -Stosa the Rows with Iris-Setosa are as follows \n",lris[lris.Class =="Iris-setosa"])
# Out:
# After filtering the data with Iris -Stosa the Rows with Iris-Setosa are as follows
#       SL   SW   PL   PW        Class
# 0   5.1  3.5  1.4  0.2  Iris-setosa
# 1   4.9  3.0  1.4  0.2  Iris-setosa
# 2   4.7  3.2  1.3  0.2  Iris-setosa
# 3   4.6  3.1  1.5  0.2  Iris-setosa
# 4   5.0  3.6  1.4  0.2  Iris-setosa
# 5   5.4  3.9  1.7  0.4  Iris-setosa
# 6   4.6  3.4  1.4  0.3  Iris-setosa
# 7   5.0  3.4  1.5  0.2  Iris-setosa
# 8   4.4  2.9  1.4  0.2  Iris-setosa
# 9   4.9  3.1  1.5  0.1  Iris-setosa
# 10  5.4  3.7  1.5  0.2  Iris-setosa
# 11  4.8  3.4  1.6  0.2  Iris-setosa
# 12  4.8  3.0  1.4  0.1  Iris-setosa
# 13  4.3  3.0  1.1  0.1  Iris-setosa
# 14  5.8  4.0  1.2  0.2  Iris-setosa
# 15  5.7  4.4  1.5  0.4  Iris-setosa
# 16  5.4  3.9  1.3  0.4  Iris-setosa
# 17  5.1  3.5  1.4  0.3  Iris-setosa
# 18  5.7  3.8  1.7  0.3  Iris-setosa
# 19  5.1  3.8  1.5  0.3  Iris-setosa
# 20  5.4  3.4  1.7  0.2  Iris-setosa
# 21  5.1  3.7  1.5  0.4  Iris-setosa
# 22  4.6  3.6  1.0  0.2  Iris-setosa
# ...

# %% [markdown]
# ### Multiply Sepal Length and width and store it under the column name "SepalExtra" in the same Iris dataframe

# %%
#### Similar to Ealier Name changes Sepal Extra name is changes to SE to easy to Access.
lris = pd.read_csv('Iris.csv')
lris.head()
# Out:
#     SL   SW   PL   PW        Class
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %%
lris["SE"]=lris["SL"]*lris["SW"]
print("The columns after Multiplication reslut is \n ",lris["SE"])
### To see the column added to the table kindly go thorugh the output which is executed after printing the below functiuon ...
lris.head()
# Out:
# The columns after Multiplication reslut is
#   0      17.85
# 1      14.70
# 2      15.04
# 3      14.26
# 4      18.00
# 5      21.06
# 6      15.64
# 7      17.00
# 8      12.76
# 9      15.19
# 10     19.98
# 11     16.32
# 12     14.40
# 13     12.90
# 14     23.20
# 15     25.08
# 16     21.06
# 17     17.85
# 18     21.66
# 19     19.38
# 20     18.36
# 21     18.87
# 22     16.56
# 23     16.83
# 24     16.32
# 25     15.00
# 26     17.00
# 27     18.20
# 28     17.68
# 29     15.04
#        ...
# 120    22.08
# 121    15.68
# 122    21.56
# 123    17.01
# 124    22.11
# 125    23.04
# 126    17.36
# 127    18.30
# 128    17.92
# 129    21.60
# 130    20.72
# 131    30.02
# 132    17.92
# 133    17.64
# 134    15.86
# 135    23.10
# 136    21.42
# 137    19.84
# 138    18.00
# 139    21.39
# 140    20.77
# 141    21.39
# 142    15.66
# 143    21.76
# 144    22.11
# 145    20.10
# 146    15.75
# 147    19.50
# 148    21.08
# 149    17.70
# Name: SE, Length: 150, dtype: float64
# ...

# %% [markdown]
# ### Find out the mean and variance for each column but for class column

# %%
lris = pd.read_csv('Iris.csv')
print("The mean of each column in\n",lris.mean())
# Out:
# The mean of each column in
#  SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %%
lris = pd.read_csv('Iris.csv')
print("The Variance  of each column in\n",lris.var())
# Out:
# The Variance  of each column in
#  SL    0.685694
# SW    0.188004
# PL    3.113179
# PW    0.582414
# dtype: float64

# %%
#### To have a complete over view on the data set .
lris = pd.read_csv('Iris.csv')
lris.describe()
# Out:
#                SL          SW          PL          PW
# count  150.000000  150.000000  150.000000  150.000000
# mean     5.843333    3.054000    3.758667    1.198667
# std      0.828066    0.433594    1.764420    0.763161
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.350000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %% [markdown]
# ### Write a function that accepts two numbers as input and prints them - Pass the Sepal length and sepal width of 5th row and print the output

# %%
### for Easy understanding i am converting Sepal lenght to SL , Sepal Width to SW and Petal Lenght to PL and Petal Width to PW 
def SL_SW(x,y):
     SL =x
     SW= y
     return SL,SW
Sepallength,SepalWidth =SL_SW(5,3.6)
print("The Sepal Length and the Sepal width of 5th row is \n ",Sepallength,SepalWidth)
# Out:
# The Sepal Length and the Sepal width of 5th row is
#   5 3.6

# %% [markdown]
# ### Find the range of all the columns in the dataset
#
# *Range = Max value - Min value (in the column)*

# %%
### for Easy understanding i am converting Sepal lenght to SL , Sepal Width to SW and Petal Lenght to PL and Petal Width to PW
lris['SL'][lris['SL'].idxmin()]
# Out:
# 4.3

# %%
lris['SL'][lris['SL'].idxmax()]
# Out:
# 7.9

# %%
print("Range in SL is \n", 7.9- 4.3)
# Out:
# Range in SL is
#  3.6000000000000005

# %%
lris['SW'][lris['SW'].idxmin()]
# Out:
# 2.0

# %%
lris['SW'][lris['SW'].idxmax()]
# Out:
# 4.4

# %%
print("Range in SW is \n", 4.4- 2.0)
# Out:
# Range in SW is
#  2.4000000000000004

# %%
lris['PL'][lris['PL'].idxmax()]
# Out:
# 6.9

# %%
lris['PL'][lris['PL'].idxmin()]
# Out:
# 1.0

# %%
print("Range in PL is \n", 6.9- 1.0)
# Out:
# Range in PL is
#  5.9

# %%
lris['PW'][lris['PW'].idxmax()]
# Out:
# 2.5

# %%
lris['PW'][lris['PW'].idxmin()]
# Out:
# 0.1

# %%
print("Range in PW is \n", 2.5- 0.1)
# Out:
# Range in PW is
#  2.4

# %% [markdown]
# ### Sort the entire dataset according to the column Petal width

# %%
### for Easy understanding i am converting Sepal lenght to SL , Sepal Width to SW and Petal Lenght to PL and Petal Width to PW
lris = pd.read_csv('Iris.csv')
print (" The result after sorting the values with the Petal Width are as follows:\n",lris.sort_values(by="PW"))
# Out:
#  The result after sorting the values with the Petal Width are as follows:
#        SL   SW   PL   PW           Class
# 32   5.2  4.1  1.5  0.1     Iris-setosa
# 13   4.3  3.0  1.1  0.1     Iris-setosa
# 37   4.9  3.1  1.5  0.1     Iris-setosa
# 9    4.9  3.1  1.5  0.1     Iris-setosa
# 12   4.8  3.0  1.4  0.1     Iris-setosa
# 34   4.9  3.1  1.5  0.1     Iris-setosa
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 27   5.2  3.5  1.5  0.2     Iris-setosa
# 28   5.2  3.4  1.4  0.2     Iris-setosa
# 29   4.7  3.2  1.6  0.2     Iris-setosa
# 30   4.8  3.1  1.6  0.2     Iris-setosa
# 33   5.5  4.2  1.4  0.2     Iris-setosa
# 36   5.5  3.5  1.3  0.2     Iris-setosa
# 38   4.4  3.0  1.3  0.2     Iris-setosa
# 39   5.1  3.4  1.5  0.2     Iris-setosa
# 42   4.4  3.2  1.3  0.2     Iris-setosa
# 46   5.1  3.8  1.6  0.2     Iris-setosa
# 47   4.6  3.2  1.4  0.2     Iris-setosa
# 48   5.3  3.7  1.5  0.2     Iris-setosa
# 49   5.0  3.3  1.4  0.2     Iris-setosa
# ...

# %% [markdown]
# ### Remove the new column "SepalExtra" from the dataframe

# %%
lris = pd.read_csv('Iris.csv')
lris["SE"]=lris["SL"]*lris["SW"]
print("The output without dropping the Column is: \n", lris.head())
# Out:
# The output without dropping the Column is:
#      SL   SW   PL   PW        Class     SE
# 0  5.1  3.5  1.4  0.2  Iris-setosa  17.85
# 1  4.9  3.0  1.4  0.2  Iris-setosa  14.70
# 2  4.7  3.2  1.3  0.2  Iris-setosa  15.04
# 3  4.6  3.1  1.5  0.2  Iris-setosa  14.26
# 4  5.0  3.6  1.4  0.2  Iris-setosa  18.00

# %%
print(" The output after dropping the column SE is \n", lris.drop("SE",axis=1))
# Out:
#  The output after dropping the column SE is
#        SL   SW   PL   PW           Class
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# 5    5.4  3.9  1.7  0.4     Iris-setosa
# 6    4.6  3.4  1.4  0.3     Iris-setosa
# 7    5.0  3.4  1.5  0.2     Iris-setosa
# 8    4.4  2.9  1.4  0.2     Iris-setosa
# 9    4.9  3.1  1.5  0.1     Iris-setosa
# 10   5.4  3.7  1.5  0.2     Iris-setosa
# 11   4.8  3.4  1.6  0.2     Iris-setosa
# 12   4.8  3.0  1.4  0.1     Iris-setosa
# 13   4.3  3.0  1.1  0.1     Iris-setosa
# 14   5.8  4.0  1.2  0.2     Iris-setosa
# 15   5.7  4.4  1.5  0.4     Iris-setosa
# 16   5.4  3.9  1.3  0.4     Iris-setosa
# 17   5.1  3.5  1.4  0.3     Iris-setosa
# 18   5.7  3.8  1.7  0.3     Iris-setosa
# 19   5.1  3.8  1.5  0.3     Iris-setosa
# 20   5.4  3.4  1.7  0.2     Iris-setosa
# ...

# %% [markdown]
# ### Take only the top 10 rows of the dataset with only first 3 columns and store it in a dataframe named "IrisSubset"

# %%
lris = pd.read_csv('Iris.csv')
print (lris.iloc[0:10,[0,1,2]])
# Out:
#     SL   SW   PL
# 0  5.1  3.5  1.4
# 1  4.9  3.0  1.4
# 2  4.7  3.2  1.3
# 3  4.6  3.1  1.5
# 4  5.0  3.6  1.4
# 5  5.4  3.9  1.7
# 6  4.6  3.4  1.4
# 7  5.0  3.4  1.5
# 8  4.4  2.9  1.4
# 9  4.9  3.1  1.5

# %%
lris_subset= (lris.iloc[0:10,[0,1,2]])
print("The lris subset with 10 rows and 3 Columsns is \n", lris_subset)
# Out:
# The lris subset with 10 rows and 3 Columsns is
#      SL   SW   PL
# 0  5.1  3.5  1.4
# 1  4.9  3.0  1.4
# 2  4.7  3.2  1.3
# 3  4.6  3.1  1.5
# 4  5.0  3.6  1.4
# 5  5.4  3.9  1.7
# 6  4.6  3.4  1.4
# 7  5.0  3.4  1.5
# 8  4.4  2.9  1.4
# 9  4.9  3.1  1.5

# %% [markdown]
# # Part-2

# %% [markdown]
# ## The dataset HR contains information collected from the survey floated by a HR within the company.
#
#
# As a part of this lab, you are expected to answer the below questions

# %% [markdown]
# ### Import numpy and Pandas

# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# ### Import the dataset (Note: The dataset is in .txt format) - Make sure to use delimiters

# %%
HR =pd.read_csv('HR_external.txt',delimiter="\t")
print("The data set after using the delimimters ",HR)
# Out:
# The data set after using the delimimters       Individual  Attrition  Age  BusinessTravel  DailyRate  Department  \
# 0           Ind1       Yes   41               1       1102           1
# 1           Ind2        No   49               2        279           2
# 2           Ind3       Yes   37               1       1373           2
# 3           Ind4        No   33               2       1392           2
# 4           Ind5        No   27               1        591           2
# 5           Ind6        No   32               2       1005           2
# 6           Ind7        No   59               1       1324           2
# 7           Ind8        No   30               1       1358           2
# 8           Ind9        No   38               2        216           2
# 9          Ind10        No   36               1       1299           2
# 10         Ind11        No   35               1        809           2
# 11         Ind12        No   29               1        153           2
# ...

# %% [markdown]
# ### Print the no of rows and columns in the dataset

# %%
HR =pd.read_csv('HR_external.txt',delimiter="\t")
HR
# Out:
#      Individual  Attrition  Age  BusinessTravel  DailyRate  Department  \
# 0           Ind1       Yes   41               1       1102           1
# 1           Ind2        No   49               2        279           2
# 2           Ind3       Yes   37               1       1373           2
# 3           Ind4        No   33               2       1392           2
# 4           Ind5        No   27               1        591           2
# 5           Ind6        No   32               2       1005           2
# 6           Ind7        No   59               1       1324           2
# 7           Ind8        No   30               1       1358           2
# 8           Ind9        No   38               2        216           2
# 9          Ind10        No   36               1       1299           2
# 10         Ind11        No   35               1        809           2
# 11         Ind12        No   29               1        153           2
# ...

# %%
print ("Theno of Rows and columns of HR-external are \n",HR.shape)
# Out:
# Theno of Rows and columns of HR-external are
#  (1470, 35)

# %% [markdown]
# ### Find out the type of each and every column in the dataset

# %%
HR =pd.read_csv('HR_external.txt',delimiter="\s+")
HR
print (" The type of each column , are as mentioned below \n", HR.dtypes)
# Out:
#  The type of each column , are as mentioned below
#  Individual                  object
# Attrition                   object
# Age                          int64
# BusinessTravel               int64
# DailyRate                    int64
# Department                   int64
# DistanceFromHome             int64
# Education                    int64
# EducationField               int64
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                       int64
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                      int64
# JobSatisfaction              int64
# MaritalStatus                int64
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# OverTime                     int64
# PercentSalaryHike            int64
# PerformanceRating            int64
# ...

# %% [markdown]
# ### Print out all the rows from 3rd column to 10th columns

# %%
HR =pd.read_csv('HR_external.txt',delimiter="\s+")
HR.head()
# Out:
#   Individual Attrition  Age  BusinessTravel  DailyRate  Department  \
# 0       Ind1       Yes   41               1       1102           1
# 1       Ind2        No   49               2        279           2
# 2       Ind3       Yes   37               1       1373           2
# 3       Ind4        No   33               2       1392           2
# 4       Ind5        No   27               1        591           2
#
#    DistanceFromHome  Education  EducationField  EmployeeCount  ...  \
# 0                 1          2               1              1  ...
# 1                 8          1               1              1  ...
# 2                 2          2               6              1  ...
# 3                 3          4               1              1  ...
# 4                 2          1               2              1  ...
#
#    RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# 0                         1             80                 0
# ...

# %%
print(" All the Rows from 3rd Column to 10 th Column are as below \n",HR.iloc[:,[2,3,4,5,6,7,8,9]])
# Out:
#  All the Rows from 3rd Column to 10 th Column are as below
#        Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0      41               1       1102           1                 1          2
# 1      49               2        279           2                 8          1
# 2      37               1       1373           2                 2          2
# 3      33               2       1392           2                 3          4
# 4      27               1        591           2                 2          1
# 5      32               2       1005           2                 2          2
# 6      59               1       1324           2                 3          3
# 7      30               1       1358           2                24          1
# 8      38               2        216           2                23          3
# 9      36               1       1299           2                27          3
# ...

# %% [markdown]
# ### Find out the no of male & female employees in the company
#
# *Hint: Use can use a condition to find out the no of 1s and 0s in gender and sum it*

# %%
### SInce the entire subset gender has only 2 inputs as "2"&"1"
####lets consider 2 as male and 1 as female basis which we can arive to the below conclusion .
##HR_subset = HR.iloc[:,[12]]
###print(HR_subset)  
HR =pd.read_csv('HR_external.txt',delimiter="\s+")
print("consider 2 as male and 1 as female in the Gender Columns\n ", pd.DataFrame(HR.Gender.value_counts()))
# Out:
# consider 2 as male and 1 as female in the Gender Columns
#      Gender
# 1     882
# 2     588

# %%
######Another Way of Finding the result .

HR =pd.read_csv('HR_external.txt',delimiter="\s+")
HR_subset = HR.iloc[:,[12]]
print(HR_subset)  

print("The no of males which is considered as the entry 2 in the Gender Subset is \n:",HR_subset[HR_subset['Gender']==2].shape)
print("The no of females which is considered as the entry 1 in the Gender Subset  is \n:",HR_subset[HR_subset['Gender']==1].shape)
# Out:
#       Gender
# 0          2
# 1          1
# 2          1
# 3          2
# 4          1
# 5          1
# 6          2
# 7          1
# 8          1
# 9          1
# 10         1
# 11         2
# 12         1
# 13         1
# 14         1
# 15         2
# 16         1
# 17         1
# 18         2
# 19         1
# 20         2
# 21         1
# 22         2
# 23         1
# 24         1
# 25         2
# 26         2
# 27         1
# 28         2
# 29         2
# ...      ...
# 1440       2
# 1441       1
# 1442       1
# 1443       1
# 1444       1
# 1445       2
# 1446       2
# 1447       1
# 1448       1
# 1449       1
# 1450       2
# 1451       2
# 1452       1
# 1453       2
# 1454       2
# 1455       1
# 1456       1
# 1457       2
# 1458       2
# 1459       1
# 1460       2
# 1461       1
# 1462       2
# 1463       1
# 1464       2
# 1465       1
# 1466       1
# 1467       1
# 1468       1
# 1469       1
#
# [1470 rows x 1 columns]
# ...

# %%
### Find out the IQR for the column - Age 

*Hint: IQR - Interquartile range = 75th percentile - 25th percentile*

# %%
HR =pd.read_csv('HR_external.txt',delimiter="\s+")
HR.loc[:,"Age"].describe()
# Out:
# count    1470.000000
# mean       36.923810
# std         9.135373
# min        18.000000
# 25%        30.000000
# 50%        36.000000
# 75%        43.000000
# max        60.000000
# Name: Age, dtype: float64

# %%
q1=HR.loc[:,"Age"].quantile(.25)
q2=HR.loc[:,"Age"].quantile(.75)
IQR =q2-q1
print ("The Inter Quartile Range of Age Column is :",IQR)
# Out:
# The Inter Quartile Range of Age Column is : 13.0

# %%
##### FIND OUT the mean , median and Variance of the Column"DailyRate".

# %%
HR =pd.read_csv('HR_external.txt',delimiter="\s+")
print (" The mean of the Column Daily rate is::",HR.loc[:,"DailyRate"].mean())
print (" The median of the Column Daily rate is::",HR.loc[:,"DailyRate"].median())
print (" The variance  of the Column Daily rate is::",HR.loc[:,"DailyRate"].var())
# Out:
#  The mean of the Column Daily rate is:: 802.4857142857143
#  The median of the Column Daily rate is:: 802.0
#  The variance  of the Column Daily rate is:: 162819.59373723628

# %% [markdown]
# ### Plot the attrition column (Since it is a categorical variable, chose the plot accordingly)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="ticks", color_codes=True)

# %%
HR =pd.read_csv('HR_external.txt',delimiter="\s+")
HR.head(2)
sns.countplot(x='Attrition',data=HR)

# %% [markdown]
# ### Plot Total working years using matplotlib plot function

# %%
HR =pd.read_csv('HR_external.txt',delimiter="\s+")
HR.head(2)
sns.distplot(HR["TotalWorkingYears"])
plt.show()
